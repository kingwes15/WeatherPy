# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * Max temperatures of cities 60 degrees north of the equator are much colder than those 60 degrees south of the equator (in December)
# * Winds speeds aren't an indicator of of warmth towards the equator however in December, majority of cities fall in the 20mph or lower wind speed
# * There is no correlation between cloudiness and latitude as it pertains to our analysis

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Build the URL = url + appid= + api_key + &q= + city + units (imperial = F, metric = C, Kelvins is the default)
#https://openweathermap.org/current
#Used this cell to see JSON structure so I can extract appropriate data 
url = "http://api.openweathermap.org/data/2.5/weather?"
appid = "APPID="
q = "&q="
#city = "new norfolk"
units = "&units="
unit = "imperial"
#query_url = url + appid + api_key + units + unit + q + city
#asdf = requests.get(query_url).json()
#print(asdf['name'])
#pprint(requests.get(query_url).json())

# %%
#Create an empty list that will only capture cities with weather data 
use_cities = []

print("Beginning Data Retrieval")
print("-----------------------------")
i = 0
set_num = 1
for city in cities:
    try:
        i = i+1  
        if i > 50:
            i = 0
            set_num = set_num + 1
        if set_num > 1:
            if i > 49:
                i = 0
                set_num = set_num + 1
        loop_url = url + appid + api_key + units + unit + q
        weather_data = requests.get(loop_url + city).json()
        test_cities = weather_data["name"]
        print(f"Processing Record {i} of Set {set_num} | {city}")
        use_cities.append(city)
    except:
        print("City not found. Skipping...")
        i = i-1
    time.sleep(1.1)

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | tahoua
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | jackson
# Processing Record 8 of Set 1 | naron
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | salinas
# City not found. Skipping...
# Processing Record 11 of Set 1 | port hedland
# Processing Record 12 of Set 1 | mporokoso
# Processing Record 13 of Set 1 | ducheng
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | darnah
# Processing Record 18 of Set 1 | broome
# Processing Record 19 of Set 1 | sitka
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | chuy
# City not found. Skipping...
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | los llanos de aridane
# Processing Record 25 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 26 of Set 1 | cockburn town
# Processing Record 27 of Set 1 | letlhakane
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | bembereke
# Processing Record 30 of Set 1 | sabha
# City not found. Skipping...
# Processing Record 31 of Set 1 | eyl
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | sept-iles
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | evensk
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 1 | liverpool
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | koygorodok
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | punta arenas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | jutai
# Processing Record 44 of Set 1 | praia da vitoria
# Processing Record 45 of Set 1 | palaikastron
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | corn island
# Processing Record 49 of Set 1 | brodowski
# Processing Record 50 of Set 1 | vaini
# Processing Record 0 of Set 2 | atuona
# Processing Record 1 of Set 2 | sorong
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | ahipara
# Processing Record 4 of Set 2 | armeria
# Processing Record 5 of Set 2 | pingliang
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | havre-saint-pierre
# Processing Record 11 of Set 2 | tamiahua
# City not found. Skipping...
# Processing Record 12 of Set 2 | margate
# Processing Record 13 of Set 2 | lompoc
# Processing Record 14 of Set 2 | dingle
# Processing Record 15 of Set 2 | alofi
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | liepaja
# Processing Record 18 of Set 2 | hambantota
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | verkh-usugli
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | linxia
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | kavaratti
# Processing Record 26 of Set 2 | albany
# City not found. Skipping...
# Processing Record 27 of Set 2 | hobart
# City not found. Skipping...
# Processing Record 28 of Set 2 | guider
# Processing Record 29 of Set 2 | rovenki
# Processing Record 30 of Set 2 | orlik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 2 | egvekinot
# City not found. Skipping...
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | pyaozerskiy
# City not found. Skipping...
# Processing Record 34 of Set 2 | tayginka
# Processing Record 35 of Set 2 | eureka
# Processing Record 36 of Set 2 | chalmette
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | port-gentil
# Processing Record 39 of Set 2 | awallan
# City not found. Skipping...
# Processing Record 40 of Set 2 | belyy yar
# Processing Record 41 of Set 2 | nanortalik
# Processing Record 42 of Set 2 | kimbe
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | te anau
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | gamba
# Processing Record 0 of Set 3 | skibbereen
# Processing Record 1 of Set 3 | karlskrona
# Processing Record 2 of Set 3 | port blair
# Processing Record 3 of Set 3 | guerrero negro
# Processing Record 4 of Set 3 | tiarei
# Processing Record 5 of Set 3 | shiraz
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | filadelfia
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | vestmannaeyjar
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | coihaique
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | teknaf
# Processing Record 16 of Set 3 | pevek
# Processing Record 17 of Set 3 | llanes
# Processing Record 18 of Set 3 | bandarbeyla
# Processing Record 19 of Set 3 | lima
# Processing Record 20 of Set 3 | naberera
# Processing Record 21 of Set 3 | namibe
# Processing Record 22 of Set 3 | dhidhdhoo
# Processing Record 23 of Set 3 | vung tau
# City not found. Skipping...
# Processing Record 24 of Set 3 | hasaki
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | amuntai
# Processing Record 27 of Set 3 | ulaangom
# Processing Record 28 of Set 3 | zhigansk
# Processing Record 29 of Set 3 | kirillov
# Processing Record 30 of Set 3 | xinqing
# Processing Record 31 of Set 3 | yuncheng
# Processing Record 32 of Set 3 | dordrecht
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | omboue
# Processing Record 36 of Set 3 | emba
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | oktyabrskoye
# Processing Record 39 of Set 3 | chicama
# Processing Record 40 of Set 3 | kuznechnoye
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | sabang
# Processing Record 43 of Set 3 | longyearbyen
# Processing Record 44 of Set 3 | dawlatabad
# Processing Record 45 of Set 3 | erenhot
# Processing Record 46 of Set 3 | san quintin
# Processing Record 47 of Set 3 | manavalakurichi
# City not found. Skipping...
# Processing Record 48 of Set 3 | espinosa
# Processing Record 49 of Set 3 | sobolevo
# Processing Record 0 of Set 4 | northam
# Processing Record 1 of Set 4 | kidal
# Processing Record 2 of Set 4 | springfield
# Processing Record 3 of Set 4 | marck
# Processing Record 4 of Set 4 | kodinsk
# Processing Record 5 of Set 4 | hualmay
# City not found. Skipping...
# Processing Record 6 of Set 4 | almeirim
# Processing Record 7 of Set 4 | karratha
# Processing Record 8 of Set 4 | oistins
# Processing Record 9 of Set 4 | camacha
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | langfang
# Processing Record 12 of Set 4 | ballina
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | estelle
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | ibb
# Processing Record 18 of Set 4 | suruc
# Processing Record 19 of Set 4 | hokitika
# City not found. Skipping...
# Processing Record 20 of Set 4 | mugur-aksy
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | marawi
# Processing Record 23 of Set 4 | clyde river
# City not found. Skipping...
# Processing Record 24 of Set 4 | katsuura
# City not found. Skipping...
# Processing Record 25 of Set 4 | sumkino
# Processing Record 26 of Set 4 | kolpashevo
# Processing Record 27 of Set 4 | saurimo
# Processing Record 28 of Set 4 | dunedin
# Processing Record 29 of Set 4 | ullapool
# Processing Record 30 of Set 4 | byron bay
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | road town
# Processing Record 34 of Set 4 | katangli
# Processing Record 35 of Set 4 | ginir
# Processing Record 36 of Set 4 | serebryanyy bor
# Processing Record 37 of Set 4 | kamien pomorski
# Processing Record 38 of Set 4 | waitati
# Processing Record 39 of Set 4 | san patricio
# City not found. Skipping...
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | tera
# City not found. Skipping...
# Processing Record 42 of Set 4 | esperance
# City not found. Skipping...
# Processing Record 43 of Set 4 | taoudenni
# City not found. Skipping...
# Processing Record 44 of Set 4 | carnarvon
# Processing Record 45 of Set 4 | diffa
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | talara
# City not found. Skipping...
# Processing Record 48 of Set 4 | shingu
# Processing Record 49 of Set 4 | pacifica
# Processing Record 0 of Set 5 | bethel
# Processing Record 1 of Set 5 | necochea
# City not found. Skipping...
# Processing Record 2 of Set 5 | warrnambool
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | villa maria
# Processing Record 5 of Set 5 | makakilo city
# Processing Record 6 of Set 5 | wairoa
# Processing Record 7 of Set 5 | newton
# Processing Record 8 of Set 5 | gari
# Processing Record 9 of Set 5 | san carlos de bariloche
# Processing Record 10 of Set 5 | sao felix do xingu
# Processing Record 11 of Set 5 | dongsheng
# Processing Record 12 of Set 5 | meulaboh
# City not found. Skipping...
# Processing Record 13 of Set 5 | romanovskaya
# Processing Record 14 of Set 5 | matam
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | macamic
# Processing Record 17 of Set 5 | nancha
# Processing Record 18 of Set 5 | ulvik
# Processing Record 19 of Set 5 | shihezi
# Processing Record 20 of Set 5 | neuquen
# Processing Record 21 of Set 5 | goderich
# Processing Record 22 of Set 5 | beauceville
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | vinh
# Processing Record 25 of Set 5 | sistranda
# Processing Record 26 of Set 5 | atbasar
# City not found. Skipping...
# Processing Record 27 of Set 5 | lexington
# Processing Record 28 of Set 5 | grand-lahou
# Processing Record 29 of Set 5 | luderitz
# City not found. Skipping...
# Processing Record 30 of Set 5 | cocachacra
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | vilcun
# Processing Record 33 of Set 5 | komsomolskiy
# Processing Record 34 of Set 5 | burns lake
# Processing Record 35 of Set 5 | whitianga
# Processing Record 36 of Set 5 | cururupu
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | itarema
# Processing Record 39 of Set 5 | hithadhoo
# Processing Record 40 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 5 | yinchuan
# Processing Record 42 of Set 5 | rosita
# Processing Record 43 of Set 5 | geraldton
# Processing Record 44 of Set 5 | westport
# Processing Record 45 of Set 5 | castro
# Processing Record 46 of Set 5 | redlands
# Processing Record 47 of Set 5 | najran
# Processing Record 48 of Set 5 | buala
# City not found. Skipping...
# Processing Record 49 of Set 5 | kudahuvadhoo
# Processing Record 0 of Set 6 | mata
# Processing Record 1 of Set 6 | lagoa
# Processing Record 2 of Set 6 | charters towers
# Processing Record 3 of Set 6 | senanga
# Processing Record 4 of Set 6 | ancona
# Processing Record 5 of Set 6 | bonavista
# Processing Record 6 of Set 6 | kuruman
# Processing Record 7 of Set 6 | mantua
# Processing Record 8 of Set 6 | cidreira
# Processing Record 9 of Set 6 | moses lake
# Processing Record 10 of Set 6 | bekhtery
# Processing Record 11 of Set 6 | saint-louis
# Processing Record 12 of Set 6 | saint-pierre
# Processing Record 13 of Set 6 | port augusta
# Processing Record 14 of Set 6 | benghazi
# Processing Record 15 of Set 6 | san rafael
# Processing Record 16 of Set 6 | cayenne
# Processing Record 17 of Set 6 | vanavara
# Processing Record 18 of Set 6 | cibitoke
# Processing Record 19 of Set 6 | kanigiri
# Processing Record 20 of Set 6 | kamwenge
# Processing Record 21 of Set 6 | svetlaya
# Processing Record 22 of Set 6 | leningradskiy
# Processing Record 23 of Set 6 | santa rosa
# Processing Record 24 of Set 6 | tongzi
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | bilibino
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | krasnovishersk
# City not found. Skipping...
# Processing Record 29 of Set 6 | betare oya
# Processing Record 30 of Set 6 | manokwari
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | juneau
# Processing Record 33 of Set 6 | bam
# Processing Record 34 of Set 6 | herat
# Processing Record 35 of Set 6 | pangnirtung
# Processing Record 36 of Set 6 | arman
# Processing Record 37 of Set 6 | pringsewu
# Processing Record 38 of Set 6 | panjakent
# Processing Record 39 of Set 6 | southbridge
# Processing Record 40 of Set 6 | north battleford
# Processing Record 41 of Set 6 | ailigandi
# Processing Record 42 of Set 6 | tilichiki
# Processing Record 43 of Set 6 | cascais
# Processing Record 44 of Set 6 | tiznit
# City not found. Skipping...
# Processing Record 45 of Set 6 | grafton
# City not found. Skipping...
# Processing Record 46 of Set 6 | kalabo
# Processing Record 47 of Set 6 | storslett
# Processing Record 48 of Set 6 | beitbridge
# Processing Record 49 of Set 6 | sao joao da barra
# City not found. Skipping...
# Processing Record 0 of Set 7 | upington
# Processing Record 1 of Set 7 | vanimo
# City not found. Skipping...
# Processing Record 2 of Set 7 | rocha
# Processing Record 3 of Set 7 | sibiti
# Processing Record 4 of Set 7 | san pedro
# Processing Record 5 of Set 7 | manoel urbano
# Processing Record 6 of Set 7 | hearst
# Processing Record 7 of Set 7 | srednekolymsk
# Processing Record 8 of Set 7 | chhindwara
# City not found. Skipping...
# Processing Record 9 of Set 7 | belmonte
# Processing Record 10 of Set 7 | peniche
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | ocean city
# Processing Record 13 of Set 7 | aksu
# Processing Record 14 of Set 7 | fairbanks
# Processing Record 15 of Set 7 | ambulu
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | zeya
# Processing Record 18 of Set 7 | praya
# Processing Record 19 of Set 7 | alice springs
# Processing Record 20 of Set 7 | gizo
# Processing Record 21 of Set 7 | sungairaya
# Processing Record 22 of Set 7 | paamiut
# City not found. Skipping...
# Processing Record 23 of Set 7 | berea
# Processing Record 24 of Set 7 | san cristobal
# City not found. Skipping...
# Processing Record 25 of Set 7 | ngunguru
# Processing Record 26 of Set 7 | thai binh
# Processing Record 27 of Set 7 | nampula
# Processing Record 28 of Set 7 | masvingo
# Processing Record 29 of Set 7 | batagay
# Processing Record 30 of Set 7 | zhangye
# Processing Record 31 of Set 7 | mehamn
# Processing Record 32 of Set 7 | sao filipe
# Processing Record 33 of Set 7 | samarai
# Processing Record 34 of Set 7 | mitsamiouli
# City not found. Skipping...
# Processing Record 35 of Set 7 | salumbar
# Processing Record 36 of Set 7 | dioknisi
# Processing Record 37 of Set 7 | zhezkazgan
# Processing Record 38 of Set 7 | santa vitoria do palmar
# Processing Record 39 of Set 7 | jacareacanga
# City not found. Skipping...
# Processing Record 40 of Set 7 | santa maria
# Processing Record 41 of Set 7 | ulladulla
# Processing Record 42 of Set 7 | tarko-sale
# Processing Record 43 of Set 7 | ucluelet
# Processing Record 44 of Set 7 | steinbach
# Processing Record 45 of Set 7 | harper
# Processing Record 46 of Set 7 | yangjiang
# Processing Record 47 of Set 7 | bintulu
# Processing Record 48 of Set 7 | comodoro rivadavia
# Processing Record 49 of Set 7 | bambous virieux
# Processing Record 0 of Set 8 | vila velha
# Processing Record 1 of Set 8 | yerbogachen
# Processing Record 2 of Set 8 | constitucion
# City not found. Skipping...
# Processing Record 3 of Set 8 | hami
# Processing Record 4 of Set 8 | ciudad bolivar
# Processing Record 5 of Set 8 | raudeberg
# Processing Record 6 of Set 8 | parole
# Processing Record 7 of Set 8 | erzin
# Processing Record 8 of Set 8 | sakaiminato
# Processing Record 9 of Set 8 | imeni babushkina
# Processing Record 10 of Set 8 | pochutla
# Processing Record 11 of Set 8 | conakry
# Processing Record 12 of Set 8 | marfino
# Processing Record 13 of Set 8 | oda
# City not found. Skipping...
# Processing Record 14 of Set 8 | grand gaube
# Processing Record 15 of Set 8 | alta floresta
# Processing Record 16 of Set 8 | caruray
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 8 | inhambane
# Processing Record 18 of Set 8 | shenzhen
# Processing Record 19 of Set 8 | kandrian
# City not found. Skipping...
# Processing Record 20 of Set 8 | solnechnyy
# Processing Record 21 of Set 8 | arkhipo-osipovka
# Processing Record 22 of Set 8 | kangaatsiaq
# Processing Record 23 of Set 8 | banyuwangi
# Processing Record 24 of Set 8 | parkes
# Processing Record 25 of Set 8 | hosingen
# Processing Record 26 of Set 8 | anadyr
# Processing Record 27 of Set 8 | le vauclin
# Processing Record 28 of Set 8 | victor harbor
# Processing Record 29 of Set 8 | lavrentiya
# Processing Record 30 of Set 8 | dalvik
# Processing Record 31 of Set 8 | ayia anna
# Processing Record 32 of Set 8 | muhos
# Processing Record 33 of Set 8 | antofagasta
# City not found. Skipping...
# Processing Record 34 of Set 8 | shimoda
# Processing Record 35 of Set 8 | christchurch
# Processing Record 36 of Set 8 | xunchang
# Processing Record 37 of Set 8 | beneditinos
# Processing Record 38 of Set 8 | taksimo
# Processing Record 39 of Set 8 | port lincoln
# Processing Record 40 of Set 8 | sarankhola
# Processing Record 41 of Set 8 | templemore
# Processing Record 42 of Set 8 | novopavlovka
# Processing Record 43 of Set 8 | mwinilunga
# Processing Record 44 of Set 8 | ponta do sol
# Processing Record 45 of Set 8 | edd
# Processing Record 46 of Set 8 | caravelas
# Processing Record 47 of Set 8 | slave lake
# City not found. Skipping...
# Processing Record 48 of Set 8 | la ronge
# Processing Record 49 of Set 8 | rawson
# Processing Record 0 of Set 9 | khasan
# City not found. Skipping...
# Processing Record 1 of Set 9 | ojinaga
# Processing Record 2 of Set 9 | lubbock
# Processing Record 3 of Set 9 | fort nelson
# City not found. Skipping...
# Processing Record 4 of Set 9 | salalah
# Processing Record 5 of Set 9 | grand-santi
# City not found. Skipping...
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | azul
# Processing Record 8 of Set 9 | soddy-daisy
# Processing Record 9 of Set 9 | siyabuswa
# Processing Record 10 of Set 9 | poum
# Processing Record 11 of Set 9 | yining
# Processing Record 12 of Set 9 | yasnyy
# Processing Record 13 of Set 9 | barao de melgaco
# Processing Record 14 of Set 9 | ust-kuyga
# Processing Record 15 of Set 9 | beringovskiy
# Processing Record 16 of Set 9 | rio grande
# Processing Record 17 of Set 9 | morros
# Processing Record 18 of Set 9 | hobyo
# City not found. Skipping...
# Processing Record 19 of Set 9 | mandalgovi
# Processing Record 20 of Set 9 | roald
# Processing Record 21 of Set 9 | praxedis guerrero
# Processing Record 22 of Set 9 | poro
# Processing Record 23 of Set 9 | muisne
# Processing Record 24 of Set 9 | manacapuru
# Processing Record 25 of Set 9 | ust-maya
# Processing Record 26 of Set 9 | nakhon phanom
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 9 | ixtapa
# Processing Record 28 of Set 9 | kaoma
# Processing Record 29 of Set 9 | duluth
# Processing Record 30 of Set 9 | bundaberg
# Processing Record 31 of Set 9 | hofn
# Processing Record 32 of Set 9 | bubaque
# Processing Record 33 of Set 9 | otradnoye
# Processing Record 34 of Set 9 | tome
# Processing Record 35 of Set 9 | visby
# Processing Record 36 of Set 9 | qasigiannguit
# Processing Record 37 of Set 9 | alihe
# Processing Record 38 of Set 9 | jiwani
# Processing Record 39 of Set 9 | luorong
# Processing Record 40 of Set 9 | laguna
# Processing Record 41 of Set 9 | novogornyy
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | papar
# Processing Record 44 of Set 9 | kununurra
# Processing Record 45 of Set 9 | sagauli
# Processing Record 46 of Set 9 | vibo valentia
# Processing Record 47 of Set 9 | chapais
# Processing Record 48 of Set 9 | hay river
# Processing Record 49 of Set 9 | mandera
# Processing Record 0 of Set 10 | chenghai
# Processing Record 1 of Set 10 | amahai
# Processing Record 2 of Set 10 | pirot
# Processing Record 3 of Set 10 | phek
# City not found. Skipping...
# Processing Record 4 of Set 10 | kutum
# Processing Record 5 of Set 10 | port shepstone
# Processing Record 6 of Set 10 | houma
# Processing Record 7 of Set 10 | vila franca do campo
# City not found. Skipping...
# Processing Record 8 of Set 10 | kayes
# Processing Record 9 of Set 10 | hirara
# Processing Record 10 of Set 10 | gorbatov
# Processing Record 11 of Set 10 | rudsar
# Processing Record 12 of Set 10 | maceio
# Processing Record 13 of Set 10 | bowen
# Processing Record 14 of Set 10 | thaton
# Processing Record 15 of Set 10 | batsfjord
# Processing Record 16 of Set 10 | antalaha
# Processing Record 17 of Set 10 | oranjestad
# Processing Record 18 of Set 10 | springbok
# Processing Record 19 of Set 10 | nicoya
# Processing Record 20 of Set 10 | marystown
# Processing Record 21 of Set 10 | coutances
# Processing Record 22 of Set 10 | sioux lookout
# Processing Record 23 of Set 10 | amargosa
# Processing Record 24 of Set 10 | kysyl-syr
# City not found. Skipping...
# Processing Record 25 of Set 10 | kalmunai
# Processing Record 26 of Set 10 | kiomboi
# Processing Record 27 of Set 10 | talcahuano
# Processing Record 28 of Set 10 | balakhta
# Processing Record 29 of Set 10 | el rosario
# Processing Record 30 of Set 10 | dukat
# Processing Record 31 of Set 10 | atar
# Processing Record 32 of Set 10 | beloha
# Processing Record 33 of Set 10 | del rio
# City not found. Skipping...
# Processing Record 34 of Set 10 | ulaanbaatar
# Processing Record 35 of Set 10 | karlskoga
# Processing Record 36 of Set 10 | lincoln
# Processing Record 37 of Set 10 | bavly
# Processing Record 38 of Set 10 | garowe
# Processing Record 39 of Set 10 | richards bay
# Processing Record 40 of Set 10 | cardston
# Processing Record 41 of Set 10 | esil
# Processing Record 42 of Set 10 | martin
# Processing Record 43 of Set 10 | launceston
# Processing Record 44 of Set 10 | camacupa
# Processing Record 45 of Set 10 | kaabong
# Processing Record 46 of Set 10 | krasnogorskoye
# Processing Record 47 of Set 10 | husavik
# Processing Record 48 of Set 10 | sur
# City not found. Skipping...
# Processing Record 49 of Set 10 | kralendijk
# Processing Record 0 of Set 11 | lao cai
# Processing Record 1 of Set 11 | arari
# Processing Record 2 of Set 11 | suicheng
# Processing Record 3 of Set 11 | almunecar
# Processing Record 4 of Set 11 | yaan
# Processing Record 5 of Set 11 | kaniama
# City not found. Skipping...
# Processing Record 6 of Set 11 | vardo
# Processing Record 7 of Set 11 | balkanabat
# Processing Record 8 of Set 11 | hamilton
# Processing Record 9 of Set 11 | flin flon
# Processing Record 10 of Set 11 | chumikan
# Processing Record 11 of Set 11 | sundarnagar
# Processing Record 12 of Set 11 | sovetskiy
# Processing Record 13 of Set 11 | namie
# Processing Record 14 of Set 11 | tres picos
# Processing Record 15 of Set 11 | marburg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 11 | sokolskoye
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | nefteyugansk
# Processing Record 19 of Set 11 | markova
# Processing Record 20 of Set 11 | arawa
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | diamantino
# Processing Record 23 of Set 11 | nago
# Processing Record 24 of Set 11 | taltal
# Processing Record 25 of Set 11 | eskilstuna
# Processing Record 26 of Set 11 | abu samrah
# Processing Record 27 of Set 11 | sambava
# Processing Record 28 of Set 11 | strezhevoy
# Processing Record 29 of Set 11 | cuamba
# City not found. Skipping...
# Processing Record 30 of Set 11 | guilin
# Processing Record 31 of Set 11 | berdigestyakh
# City not found. Skipping...
# Processing Record 32 of Set 11 | mildura
# Processing Record 33 of Set 11 | pisco
# Processing Record 34 of Set 11 | marzuq
# Processing Record 35 of Set 11 | hovd
# Processing Record 36 of Set 11 | kupang
# Processing Record 37 of Set 11 | pavilosta
# Processing Record 38 of Set 11 | phan thiet
# Processing Record 39 of Set 11 | winnemucca
# Processing Record 40 of Set 11 | dibulla
# Processing Record 41 of Set 11 | zhob
# Processing Record 42 of Set 11 | guozhen
# Processing Record 43 of Set 11 | lagos
# City not found. Skipping...
# Processing Record 44 of Set 11 | yumen
# Processing Record 45 of Set 11 | pierre
# Processing Record 46 of Set 11 | bonga
# Processing Record 47 of Set 11 | ocampo
# Processing Record 48 of Set 11 | grootfontein
# City not found. Skipping...
# Processing Record 49 of Set 11 | nabire
# Processing Record 0 of Set 12 | arys
# Processing Record 1 of Set 12 | biak
# Processing Record 2 of Set 12 | brest
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Create empty list that will be filled once the loop is processed
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Loop through the API to create the list for the DataFrame
for city in use_cities:
    loop_url = url + appid + api_key + units + unit + q
    weather_data = requests.get(loop_url + city).json()
    #Create list for: Cloudiness, Country, Date, Humidity, Latitude, Longitude, Max Temperature (F), & Wind Speed
    Cloudiness.append(weather_data["clouds"]["all"])
    Country.append(weather_data["sys"]["country"])
    Date.append(weather_data["dt"])
    Humidity.append(weather_data["main"]["humidity"])
    Lat.append(weather_data['coord']['lat'])
    Lng.append(weather_data['coord']['lon'])
    Max_Temp.append(weather_data["main"]["temp_max"])
    Wind_Speed.append(weather_data["wind"]["speed"])
    #Take a 1.1 second break before sending another request to the API
    time.sleep(1.1)

#Create DF
weather_df = pd.DataFrame({
    "City": use_cities,
    "Cloudiness": Cloudiness,
    "Country": Country,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "Max Temp": Max_Temp,
    "Wind Speed": Wind_Speed
})

#Export DF to a CSV
weather_df.to_csv("WeatherPy.csv", index = False, header = True)

# %%
#Display Column headers and the row count
weather_df.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
#Top 5 rows of DF
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          rikitea          68      PF  1545772746        99 -23.12 -134.97
# 1  arraial do cabo          40      BR  1545768000        69 -22.97  -42.02
# 2       bredasdorp           0      ZA  1545771600        56 -34.53   20.04
# 3           kodiak           1      US  1545771300        65  39.95  -94.76
# 4           tahoua           0      NE  1545772751        33  14.89    5.26
#
#    Max Temp  Wind Speed
# 0     78.44       15.30
# 1     80.60        6.93
# 2     73.40        4.70
# 3     48.92        9.17
# 4     61.75       10.76

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Get todays date so chart titles dynamically display the date in which the code is ran and the weather data represents
import datetime
today = datetime.date.today()  
year = today.year
month = today.month
day = today.day
date = f"{month}/{day}/{year}"

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature {date}")
plt.savefig(f"City Latitude vs. Max Temperature {date.replace('/','.')}.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"], edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity {date}")
plt.savefig(f"City Latitude vs. Humidity {date.replace('/','.')}.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness {date}")
plt.savefig(f"City Latitude vs. Cloudiness {date.replace('/','.')}.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"], edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")
plt.title(f"City Latitude vs. Wind Speed {date}")
plt.savefig(f"City Latitude vs. Wind Speed {date.replace('/','.')}.png")
plt.show()
